# %% [markdown]
# # User Item Matrix
#
# ---

# %%
INPUT = r'..\..\data\processed\CF\Final_rating.csv'

OUTPUT = r'..\..\models\CF\U_I_M.pkl'

# %% [markdown]
# # importing

# %%
import pandas as pd
# import matplotlib.pyplot as plt
# import seaborn as sns
import joblib

# %%
rating_df = pd.read_csv(INPUT)

# %%
rating_df
# Out:
#        User-ID        ISBN  Book-Rating  \
# 0       276925  002542730X           10
# 1       277427  002542730X           10
# 2        10030  002542730X            7
# 3        11676  002542730X            6
# 4        12538  002542730X           10
# ...        ...         ...          ...
# 59354   247752  1551669633           10
# 59355   227520  0671776096           10
# 59356   235392  0671776096            7
# 59357   247447  0671776096           10
# 59358   258690  0671776096           10
#
#                                                    Title             Author  \
# 0      Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner
# 1      Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner
# 2      Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner
# 3      Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner
# 4      Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner
# ...

# %% [markdown]
# ## ok let's calculate the user item matrix

# %%
user_item_m = rating_df.pivot(columns='Title' , index= 'User-ID' , values='Book-Rating')

# %%
user_item_m
# Out:
# Title     Earth Prayers From around the World: 365 Prayers, Poems, and Invocations for Honoring the Earth  \
# User-ID
# 254                                                    NaN
# 507                                                    NaN
# 882                                                    NaN
# 1424                                                   NaN
# 1435                                                   NaN
# ...                                                    ...
# 277478                                                 NaN
# 277639                                                 NaN
# 278137                                                 NaN
# 278188                                                 NaN
# 278418                                                 NaN
#
# Title     Murder of a Sleeping Beauty (Scumble River Mysteries (Paperback))  \
# User-ID
# 254                                                    NaN
# ...

# %% [markdown]
# ## Let's calculate the sparsity for this matrix

# %%
1- 59359 / (1749*6473)
# Out:
# 0.9947568635587664

# %% [markdown]
# ---

# %%
joblib.dump(user_item_m , OUTPUT)
# Out:
# ['..\\..\\models\\CF\\U_I_M.pkl']
